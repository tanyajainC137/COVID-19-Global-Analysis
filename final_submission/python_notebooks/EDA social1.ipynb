# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %matplotlib inline

# %%
sns.set(style="ticks", color_codes=True)

# %%
data = pd.read_excel('../Data/social/acaps_covid19_government_measures_dataset.xlsx', sheet_name = 'Database')
data.head()
# Out:
#    ID      COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE REGION  \
# 0   1  Afghanistan  AFG              NaN    NaN   Asia
# 1   2  Afghanistan  AFG            Kabul    NaN   Asia
# 2   3  Afghanistan  AFG              NaN    NaN   Asia
# 3   4  Afghanistan  AFG              NaN    NaN   Asia
# 4   5  Afghanistan  AFG              NaN    NaN   Asia
#
#                                LOG_TYPE  \
# 0  Introduction / extension of measures
# 1  Introduction / extension of measures
# 2  Introduction / extension of measures
# 3  Introduction / extension of measures
# 4  Introduction / extension of measures
#
#                                  CATEGORY  \
# 0                  Public health measures
# 1                  Public health measures
# 2                  Public health measures
# 3  Governance and socio-economic measures
# 4                       Social distancing
#
#                                              MEASURE TARGETED_POP_GROUP  \
# 0  Health screenings in airports and border cross...                 No
# 1                  Isolation and quarantine policies                 No
# 2                                Awareness campaigns                 No
# 3  Emergency administrative structures activated ...                 No
# 4                            Limit public gatherings                 No
#
#                     COMMENTS NON_COMPLIANCE DATE_IMPLEMENTED  \
# 0                        NaN            NaN       2020-02-12
# 1                        NaN            NaN       2020-02-12
# 2                        NaN            NaN       2020-02-12
# 3                        NaN            NaN       2020-02-12
# 4  Nevruz festival cancelled            NaN       2020-03-12
#
#                SOURCE SOURCE_TYPE  \
# 0  Ministry of Health  Government
# 1  Ministry of Health  Government
# 2  Ministry of Health  Government
# 3  Ministry of Health  Government
# 4                  AA       Media
#
#                                                 LINK ENTRY_DATE  \
# 0  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 1  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 2  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 3  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 4  https://www.aa.com.tr/en/asia-pacific/coronavi... 2020-03-14
#
#   Alternative source
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
 x = pd.Series(data.columns)

# %%
data.columns= x.str.lower()

# %%
data.head(5)
# Out:
#    id      country  iso admin_level_name  pcode region  \
# 0   1  Afghanistan  AFG              NaN    NaN   Asia
# 1   2  Afghanistan  AFG            Kabul    NaN   Asia
# 2   3  Afghanistan  AFG              NaN    NaN   Asia
# 3   4  Afghanistan  AFG              NaN    NaN   Asia
# 4   5  Afghanistan  AFG              NaN    NaN   Asia
#
#                                log_type  \
# 0  Introduction / extension of measures
# 1  Introduction / extension of measures
# 2  Introduction / extension of measures
# 3  Introduction / extension of measures
# 4  Introduction / extension of measures
#
#                                  category  \
# 0                  Public health measures
# 1                  Public health measures
# 2                  Public health measures
# 3  Governance and socio-economic measures
# 4                       Social distancing
#
#                                              measure targeted_pop_group  \
# 0  Health screenings in airports and border cross...                 No
# 1                  Isolation and quarantine policies                 No
# 2                                Awareness campaigns                 No
# 3  Emergency administrative structures activated ...                 No
# 4                            Limit public gatherings                 No
#
#                     comments non_compliance date_implemented  \
# 0                        NaN            NaN       2020-02-12
# 1                        NaN            NaN       2020-02-12
# 2                        NaN            NaN       2020-02-12
# 3                        NaN            NaN       2020-02-12
# 4  Nevruz festival cancelled            NaN       2020-03-12
#
#                source source_type  \
# 0  Ministry of Health  Government
# 1  Ministry of Health  Government
# 2  Ministry of Health  Government
# 3  Ministry of Health  Government
# 4                  AA       Media
#
#                                                 link entry_date  \
# 0  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 1  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 2  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 3  https://moph.gov.af/en/moph-held-emergency-mee... 2020-03-14
# 4  https://www.aa.com.tr/en/asia-pacific/coronavi... 2020-03-14
#
#   alternative source
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
data.isnull().sum()
# Out:
# id                        0
# country                   0
# iso                       0
# admin_level_name      11034
# pcode                 12342
# region                    0
# log_type                  0
# category                  0
# measure                   0
# targeted_pop_group        0
# comments                145
# non_compliance         1260
# date_implemented        287
# source                   20
# source_type              14
# link                     31
# entry_date                0
# alternative source    11261
# dtype: int64

# %%
data['non_compliance'].value_counts()
# Out:
# Not applicable                  8450
# Not available                   1498
# Up to detention                  286
# Fines                            236
# Arrest/Detention                 192
# Refusal to enter the country     185
# Other (add in comments)          126
# Legal action                      40
# fines                             39
# not applicable                    19
# not available                      6
# Deportation                        5
# Name: non_compliance, dtype: int64

# %%
category = data['category'].value_counts()
category = category.reset_index()
category
# Out:
#                                     index  category
# 0                  Public health measures      3970
# 1                   Movement restrictions      2651
# 2                       Social distancing      2609
# 3  Governance and socio-economic measures      2495
# 4                                Lockdown       612
# 5                  Humanitarian exemption         5

# %%
data['measure'].value_counts()
# Out:
# Economic measures                                               1709
# Strengthening the public health system                          1082
# Limit public gatherings                                         1056
# Closure of businesses and public services                        969
# Isolation and quarantine policies                                676
# Domestic travel restrictions                                     541
# Awareness campaigns                                              487
# Schools closure                                                  484
# Partial lockdown                                                 467
# Border closure                                                   453
# General recommendations                                          446
# International flights suspension                                 421
# Other public health measures enforced                            403
# Emergency administrative structures activated or established     397
# Curfews                                                          379
# Visa restrictions                                                339
# Surveillance and monitoring                                      299
# State of emergency declared                                      248
# Health screenings in airports and border crossings               235
# Requirement to wear protective gear in public                    221
# Testing policy                                                   198
# Full lockdown                                                    120
# Changes in prison-related policies                                97
# Psychological assistance and medical social work                  91
# Additional health/documents requirements upon arrival             90
# Military deployment                                               89
# Border checks                                                     74
# Limit product imports/exports                                     52
# Amendments to funeral and burial regulations                      52
# Mass population testing                                           45
# Checkpoints within the country                                    43
# strengthening the public health system                            25
# Lockdown of refugee/idp camps or other minorities                 24
# curfews                                                            7
# Humanitarian exemptions                                            5
# limit public gatherings                                            4
# Complete border closure                                            3
# testing policy                                                     3
# awareness campaigns                                                3
# Obligatory medical tests not related to COVID-19                   2
# requirement to wear protective gear in public                      2
# full lockdown                                                      1
# Name: measure, dtype: int64

# %%
for i in category['index']:
    healthcare = data[data['category']==i]
    healthcare = healthcare['measure'].value_counts()
    healthcare = healthcare[:5]
    healthcare = pd.DataFrame(healthcare)
    healthcare.reset_index(inplace = True)
    healthcare.columns = ['measure', 'count']
    ax = sns.barplot(x = 'count', y = 'measure', data = healthcare)
    plt.title(i)
    plt.xlabel('No of instances')
    
    total = sum(healthcare['count'])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100*p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
    plt.show()

# %%
#Economic measures has been the highest used measure in all of the categories at 1700+ instances.

# %%
region = data['region'].value_counts()

plt.pie(region, labels = region.index)
plt.show()

# %%
for i in region.index:
    loc = data[data['region']==i]
    loc = loc['category'].value_counts()
#loc = loc[:]
    loc = pd.DataFrame(loc)
    loc.reset_index(inplace = True)
    loc.columns = ['category', 'count']
    ax = sns.barplot(x = 'count', y = 'category', data = loc)
    plt.title(i)
    plt.xlabel('No. of instances')
    
    total = sum(loc['count'])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100*p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

    plt.show()

# %%
#Middle East has minimun Public Health and Gov & Socio-Economic Measures and highest Lockdown and Movement Restrictions
#Americas has the least social distancing
#Europe has the highest Gov & Socio-Economic Measures and Least Lockdown
#Pacific has the second least Lockdown
#Asia has highest Public Health Measures
